# %%
"""docstring: The following game was my first time coding and I am very happyto have 
made it about the movie "Twilight"(2008). Being a teenager I loved this movie, its storyline 
and the book it is based on a lot and I thought it is a great opportunity to build a game about 
it using the Python practices taught by Professor Kusterer. The game is called "3 Minutes in Forks",
as it should take the user 3 minutes to finish it and the story takes place in a town named "Forks".
The user is led through some sceneries inspired by the movie and gets to choose their path.
The "right" path leads them to a small battle and lets them survive the game. The "wrong" choices leads 
the player to being killed.
I hope for the users who know the movie to relive the mystical vibe of Twilight in my game!"""

#import random library to use later in battle game
import random as rd


#definiton of the first function, a questionnaire which is the first part of the game
def questionnaire():

#welcome text and telling user to hit enter to continue
    input(prompt = f"""
{'*' * 100}

Welcome to 3 Minutes in Forks! 

A few questions before we start...

Press ENTER or type anything to continue
""")
#user input of their name, while loop
    while True:
        name = input(prompt = f"""
{'*' * 100}

What is your name?\n
""")
        #if nothing is typed ask user to type something
        if name == "": 
            print("Please type something")
        else:
            break
    while True:
#user input of users city  
        city = input(prompt = """
Which city do you come from?\n
""")
        #if nothing is typed ask user to type something
        if city == "": 
            print("Please type something")
        else:
            break
    while True:
#user input of favorite song    
        song = input(prompt = """
What is your favorite song (e.g. Alejandro by Lady Gaga)?\n
""")
        #if nothing is typed ask user to type something
        if song == "": 
            print("Please type something")
        else:
            break
########## PHASE1 ################    
#print of an intro text containing variables filled out by user
    print(f"""
{'*' * 100}

{name.strip().capitalize()}, you have just moved here from {city.strip().capitalize()} yesterday and arrived in rainy, 
cloudy, Washington State - to be more specific a small town called Forks with 
a population of 3000 people. You live with your dad and do not know anyone here.

You make yourself on your way to your first day at school. Arriving at the 
parking lot, you have your earphones on and are playing {song.strip().capitalize()} loudly.
Suddenly a car almost crashes into you! You for a second see your life 
flashing before your eyes... but then suddenly out of nowhere a guy pushes 
the car away from you and saves your life. How is that possible? A lot of 
students around you stop and stare at you.

You remember you had heard that there are vampires and werewolves in Forks. 
Maybe you just met the first vampire... """)
#telling user to hit enter to continue
    input(prompt = f"""
Press ENTER or type anything to continue
""")
#print of story leading to function phase1
    print(f"""
{'*' * 100}    
    
Later, during lunch you do not know where to sit.
You have to choose between 2 tables:
Table 1, with the guy or... probably vampire who saved your life, sitting 
with his friends.
Table 2, you don't know anyone there.
""")
    phase1()


#definition of function phase1 which lets user choose between two tables
def phase1():
    result=0
#while loop containing choices for the table to sit on
    while True:
        choice1 = input(prompt = """
Where are you going to sit?

1) vampires
2) humans

Please type your answer:

""")
        #if user types in following special characters, delete them by replacing with ""
        for x in "()!%&/.=":
            choice1 = choice1.replace(x, "")
#try if choice is an integer
        try:
            choice1 = int(choice1)
#casefold and remove spaces from answer
        except:
            choice1 = choice1.casefold().strip()
            large = len(choice1)
#if user doesnt type anything ask them to type something
        if choice1 == "": 
            print("Please type something")
            input(prompt = """
Press ENTER or type anything to continue
""")
#if condition for when choice is an integer
        elif type(choice1) == int:
#if user types 1 it jumps to phase 2a
            if choice1 == 1:
                phase2a()
                break
#if user types 2 it jumps to 2b
            elif choice1 == 2:
                phase2b()
                break
#in other cases it leads to the errorfunction
            else:
                errorfunction()
#user is told to use at least 3 letters 
        elif large < 3:
            print("Please use at least 3 letters and try again!")
            phase1()
            break
#is user types characters contained in vampires it leads to phase 2a
        elif choice1 in "vampire" or "vampire" in choice1:
            phase2a()
            break
#is user types characters contained in table a it leads to phase 2a            
        elif choice1 in "table a" or "table a" in choice1:
            phase2a()
            break
#is user types characters contained in humans it leads to phase 2b
        elif choice1 in "humans" or "humans" in choice1:
            phase2b()
            break
#is user types characters contained in table b it leads to phase 2b            
        elif choice1 in "table b" or "table b" in choice1:
            phase2b()
            break
#other cases errorfunction is shown            
        else:
            errorfunction()
        
#definition of error function if user types in unknown value
def errorfunction():
    print("""
You do not seem to have used one of the given choices. Please try again!""")
#telling user to press enter to restart    
    input(prompt = """
Please press ENTER or type anything to restart.
""")
#definition of die-errorfunction that appears when player dies, yes/no loop    
def dieerrorfunction():
    while True:
        print(f"""
Sorry - you died!""")
        answer = input(prompt = """Do you want to restart the game?

""")
#casefold the users input and remove spaces, if yes then restart game
        if answer.casefold().strip() in ('y', 'yes', 'sure', 'yeah', 'ok', 'okay'):
            questionnaire()
            break
#casefold the users input and remove spaces, if no then let user exit game           
        elif answer.casefold().strip() in ('n', 'no', 'nope'):
            print("""
Too bad ¯\_(ツ)_/¯""")
            input(prompt = """
Please press ENTER to exit.
""")
            break
        else:
            print("""Please type either "yes" or "no".
""")

            
            
########## PHASE2 ################

#function of PHASE2a of the game: decision of becoming a vampire
def phase2a():
    
#While Loop for the user to decide the yes/no question of becoming a vamprie
    while True:
        
#text describing next phase 2a where player sits with the vampires and gets asked if they want to become one
        choice2 = input(prompt = f"""
{'*' * 100}

You sit at the mysterious guys' table - Edward Cullen is his name. You become 
friends with him and and his family. You were right - they are vampires. You 
start spending a lot of time with them and they tell you about their secrets.

Time goes on. The Cullens tell you about their enemies Victoria and Laurent. 
It is against the "vampire law" for vampires to spend so much time with humans, 
let alone tell them their big secret. It becomes dangerous for you to stay human. 
It is possible their enemies would come after you.

So they ask you if you want to become a vampire.

You are aware of that with turning into a vampire comes immortality, drinking 
blood to survive, never aging... having to relocate regularly in order not to 
be noticed.

Do you take the risk? 



""")
#if user types in following special characters, delete them by replacing with ""
        for x in "()!%&/.=":
            choice2 = choice2.replace(x, "")
#try if choice2 is an integer
        try:
            choice2 = int(choice2)
#Casefolding the variable and removing the spaces with strip
        except:
            choice2 = choice2.casefold().strip()
#if the user types in an integer
        if type(choice2) == int:
#if the user types "1" the game jupms to phase 3a
            if choice2 == 1:
                phase3a()
                break
#if the user types "2" the game jupms to phase 3b
            elif choice2 == 2:
                phase3b()
                break
#reference to error function
            else:
                errorfunction()
                        
#if the user types "yes" the game jupms to phase 3a
        elif choice2 in ('y', 'yes', 'sure', 'yeah', 'ok', 'okay'):
            phase3a()
            break
#if the user types "no" the game jupms to phase 3b
        elif choice2 in ('n', 'no', 'nope'):
            phase3b()
            break
#reference to error function
        else:
            errorfunction()



#function of PHASE2b of the game: being human and getting a second chance to become a vampire, while loop of answers

def phase2b():
    
    while True:
        choice4 = input(prompt = f"""
{'*' * 100}

You become friends with the humans and your life is boring now. You just study 
and sometimes hang out with your classmates Mike and Jessica.

One day when you're on your way home from a study group at Jesscia's, you get 
attacked by a vampire! He bites you and starts drinking your blood, wanting to 
kill you.
Another vampire suddenly comes and pulls the attacker away from you! He says 
his name is Edward and he offers you a way not to die by turning you into a 
vampire.

You do not have much time to decide. What will your choice be? 
1) You become a vampire.
2) You choose to die.

Please type your answer:
""")
#Trying to transform the variable into an integer
        for x in "()!%&/.=":
            choice4 = choice4.replace(x, "")
#Trying to check if the variable is an integer        
        try:
            choice4 = int(choice4)
#Casefolding the variable and removing the spaces with strip
        except:
            choice4 = choice4.casefold().strip()
#if the user types in an integer
        if type(choice4) == int:
#if the user types "1" the game jupms to phase 3a
            if choice4 == 1:
                phase3a()
                break
#if the user types "2" the game jupms to phase 3b
            elif choice4 == 2:
                dieerrorfunction()
                break
#reference to error function
            else:
                errorfunction()
            
            
#if the user types "yes" the game jupms to phase 3a
        elif choice4 in "you become a vampire" or "vamp" in choice4:
            phase3a()
            break
#if the user types "no" the game jupms to phase 3b
        elif choice4 in "you choose to die" or "die" in choice4:
            dieerrorfunction()
            break
#reference to error function
        else:
            errorfunction()

    
            
########## PHASE3 ################    
#function of PHASE3a of the game: decision of a gift
   
def phase3a():
        
    while True:
        choice3 = input(prompt = f"""

{'*' * 100}

Congratulations, you now have gained the gift of immortality! Your eye color 
has turned red, your skin has become cold as stone you feel the urge to drink 
blood - but nothing can hurt you anymore.

In addition there is one more benefit that vampires gain after turning: a 
special "gift" or skill.

What do you want your special power to be? You get to decide:

1) reading minds
2) running very fast
3) seeing the future

Which one do you choose?\n

""")
#while loop of 3 gift choices
        for x in "()!%&/.=":
            choice3 = choice3.replace(x, "")
#try if choice3 is an integer
        try:
            choice3 = int(choice3)
#casefold choice3 and remove the spaces
        except:
            choice3 = choice3.casefold().strip()
#in case an integer is typed by the user
        if type(choice3) == int:
#1 leads to phase 4a
            if choice3 == 1:
                phase4a()
                break
#2 leads to phase 4b
            elif choice3 == 2:
                phase4b()
                dieerrorfunction()
                break
#3 leads to phase 4c
            elif choice3 == 3:
                phase4c()
                dieerrorfunction()
                break
#else the errorfunction will appear
            else:
                errorfunction()
#if choice is contained in the string below, it leads to phase4a
        elif choice3 in "reading minds" or "reading" in choice3:
            phase4a()
            break
#if choice is found in the string below, it leads to phase4b
        elif choice3 in "running very fast" or "running" in choice3:
            phase4b()
            dieerrorfunction()
            break
#if choice is found in the string below, it leads to phase4c
        elif choice3 in "seeing the future" or "future" in choice3:
            phase4c()
            dieerrorfunction()
            break
#otherwise to an errrorfunction
        else:
            errorfunction()
                  
#phase 3b where user chooses to stay human, leading them to die    
def phase3b():
    print(f"""
It is an understandable choice. But as a human you are not allowed to hang out 
with vampires and most importantly: you are not allowed to know their secret. 
The heads of vampires, the Volturi, located in Italy, hear about this and send 
someone after you and kill you.
""")
    dieerrorfunction()
########## PHASE4 ################   
#phase 4a describing the choice of being turned into a vampire and intro into battle game
def phase4a():
    input(prompt = f"""
{'*' * 100}

You made a wise choice. Reading the minds of humans and vampires has made it 
possible for you to become a part of the Cullen clan. You always think ahead 
of others and your special skills help you dominate the group of vampires in 
Forks.

One evening you and the Cullens accidentally enter a part of town which is 
considered werewolf territory and you get into a fight with the werewolves.

You need to now help the Cullens win the battle against them!

Press ENTER or type anything to see the battle instructions.

""")
#instruction print for battle and telling user to hit enter to continue    
    input(prompt = """
--- Battle Instructions: ---
By PRESSING ENTER you battle 1 time against the werewolves.
You then find out if you were stronger or the werewolves.

You get 3 chances to win!

Press ENTER or type anything to perform the 1st battle:

""")
#battle game against werewolves consisting of loop, a random number between 0 and 2 leading toplayer has 3
#chances to either win or lose
#empty result
    result =''
    #3 tries
    y = 3
    #0 tries used
    x = 0
    #while the tries are smaller than 3, add one to tries used, and subtract 1 from the lives
    while x < 3: 
        x += 1
        y -=1
        #lead the battle function where the random function is defined
        result = battle()
        #if element a happens, user loses and is asked to try again
        if result == 'a':
            print (f"""
{'*' * 100}

The werewolves were stronger - you lost!

You have {y} chances left!
""")
            yesorno = input(prompt = """Do you want to try again?

""")
            #if the input of the user is in the text yes then they can press enter or type anything to continue
            if yesorno.strip().casefold() in ('y', 'yes', 'sure', 'yeah', 'ok', 'okay'):
                input(prompt = """
Press ENTER to continue

""")
            #typing no leads to the die function
            elif yesorno.strip().casefold() in ('n', 'no', 'nope'):
                dieerrorfunction()
                break
            #otheriwse errorfunction
            else:
                errorfunction()       
        #in case element b happens by the random function, the user wins and sees the winning message
        elif result == 'b':
            print(f"""
{'*' * 100}

CONGRATULATIONS!!! You won 3 Minutes in Forks! :)



__   __              _    _                _ 
\ \ / /             | |  | |              | |
 \ V / ___   _   _  | |  | |  ___   _ __  | |
  \ / / _ \ | | | | | |/\| | / _ \ | '_ \ | |
  | || (_) || |_| | \  /\  /| (_) || | | ||_|
  \_/ \___/  \__,_|  \/  \/  \___/ |_| |_|(_
                                             
                                             

""")
            break

                        
#phase 4b where user chose the gift to run fast leading them to die    
def phase4b():
    print(f"""
{'*' * 100}

Running super fast is a great gift to have. But Victoria, the greatly feared, 
and super fast vampire who has been after the Cullens for a long time, hears 
of that you are a part of their clan now and comes to get you. She is faster 
than you and kills you.
""")
    dieerrorfunction()
#phase 4c where user chose to see the future, leading them to die    
def phase4c():
    print(f"""
{'*' * 100}

Seeing the future might sound like a useful gift to have. Although, the 
decisions of the people and vampires change the future constantly. You are not 
able to see the spontaneous plans of gretaly feared Victoria and Laurent 
attacking you. They get to you and kill you.


""")
    dieerrorfunction()
#definition of battle function, which allows for a random integer to be chosen between 0 and 1    
def battle():
    listofrandomevent = ['a', 'b']
    choice  = rd.randint(0, 1)
    pick = listofrandomevent[choice]
    return pick
#start of the game
questionnaire()
# Out:
# ****************************************************************************************************
#
# Welcome to 3 Minutes in Forks!
#
# A few questions before we start...
#
# Press ENTER or type anything to continue
#
#
# ****************************************************************************************************
#
# What is your name?
#
# nika
#
# Which city do you come from?
#
# vienna
#
# What is your favorite song (e.g. Alejandro by Lady Gaga)?
#
# alejandro
#
# ****************************************************************************************************
#
# Nika, you have just moved here from Vienna yesterday and arrived in rainy,
# cloudy, Washington State - to be more specific a small town called Forks with
# a population of 3000 people. You live with your dad and do not know anyone here.
#
# You make yourself on your way to your first day at school. Arriving at the
# parking lot, you have your earphones on and are playing Alejandro loudly.
# ...
